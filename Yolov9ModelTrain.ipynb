# %% [markdown]
# <a href="https://colab.research.google.com/github/Kushagra3219/Exploratory-Data-Analysis/blob/main/Yolov9ModelTrain.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#step 1: Install Ultralytics

# !pip install Ultralytics --upgrade -q
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.1/1.1 MB 62.8 MB/s eta 0:00:00

# %%
#step 2: Load model

from ultralytics import YOLO
model = YOLO('yolov9c.pt')
# Out:
# Creating new Ultralytics Settings v0.0.6 file ✅
# View Ultralytics Settings with 'yolo settings' or at '/root/.config/Ultralytics/settings.json'
# Update Settings with 'yolo settings key=value', i.e. 'yolo settings runs_dir=path/to/dir'. For help see https://docs.ultralytics.com/quickstart/#ultralytics-settings.
# ...

# %%
model.info(verbose=True)
# Out:
# YOLOv9c summary: 358 layers, 25,590,912 parameters, 0 gradients, 104.0 GFLOPs
# (358, 25590912, 0, 104.02268160000003)

# %%
print(model.model)
# Out:
# DetectionModel(
#   (model): Sequential(
#     (0): Conv(
#       (conv): Conv2d(3, 64, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn): BatchNorm2d(64, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#       (act): SiLU(inplace=True)
#     )
#     (1): Conv(
#       (conv): Conv2d(64, 128, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn): BatchNorm2d(128, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#       (act): SiLU(inplace=True)
#     )
#     (2): RepNCSPELAN4(
#       (cv1): Conv(
#         (conv): Conv2d(128, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn): BatchNorm2d(128, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#         (act): SiLU(inplace=True)
#       )
#       (cv2): Sequential(
#         (0): RepCSP(
#           (cv1): Conv(
#             (conv): Conv2d(64, 32, kernel_size=(1, 1), stride=(1, 1), bias=False)
# ...

# %%
import cv2
import matplotlib.pyplot as plt

# %%
image_path = '/content/carss.jpg'
image = cv2.imread(image_path)

# %%
result = model(image)
# Out:
# 0: 640x640 3 persons, 7 cars, 49.3ms
# Speed: 12.5ms preprocess, 49.3ms inference, 18.4ms postprocess per image at shape (1, 3, 640, 640)

# %%
for r in result:
  r.save(filename='result.jpg')

# %%
img_result = cv2.imread('result.jpg')
img_rgb = cv2.cvtColor(img_result, cv2.COLOR_BGR2RGB)
plt.figure(figsize=(10,8))
plt.imshow(img_rgb)
plt.axis('off')
plt.title('Inference - yolov9c')
# Out:
# Text(0.5, 1.0, 'Inference - yolov9c')

# %%
from google.colab import drive

# %%
drive.mount('content/gdrive')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipython-input-1636198511.py in <cell line: 0>()
# ----> 1 drive.mount('content/gdrive')
#
# /usr/local/lib/python3.12/dist-packages/google/colab/drive.py in mount(mountpoint, force_remount, timeout_ms, readonly)
#      95 def mount(mountpoint, force_remount=False, timeout_ms=120000, readonly=False):
#      96   """Mount your Google Drive at the specified mountpoint path."""
# ---> 97   return _mount(
#      98       mountpoint,
#      99       force_remount=force_remount,
#
# /usr/local/lib/python3.12/dist-packages/google/colab/drive.py in _mount(mountpoint, force_remount, timeout_ms, ephemeral, readonly)
#     198     normed = _os.path.normpath(mountpoint)
#     199     if '/' in normed and not _os.path.exists(_os.path.dirname(normed)):
# --> 200       raise ValueError('Mountpoint must be in a directory that exists')
# ...

# %%
ROOT_DIR = '/content/gdrive/MY DRIVE/my_dataset'

# %%
# !pip install ultralytics
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.1/1.1 MB 47.7 MB/s eta 0:00:00
# ...

# %%
from ultralytics import YOLO
model = YOLO('yolov9t.pt')  #pt -> pre-trained , ymal -> scratch model

# %%
import os

# %%
# model.train(
#     data = os.path.join(ROOT_DIR, 'google_colab_config.yaml'),
#     epochs = 1,
#     imgsz = 640,
#     batch = 16,
#     name= 'yolov9_costom'
#     freeze= 10 # Freeze first 10 layer
# )

# %%
results = model.train(data=os.path.join(ROOT_DIR,'google_colab_config.yaml'),epochs =1 )
# Out:
# Ultralytics 8.3.228 🚀 Python-3.12.12 torch-2.8.0+cu126 CUDA:0 (Tesla T4, 15095MiB)
# ...
